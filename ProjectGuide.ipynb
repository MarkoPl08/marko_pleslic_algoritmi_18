# %% [markdown]
# <h1> Basic information About The Project: </h1>
# <p> This is a template file for Optimizaion Algorithms Based on Evolutionary Computing. Please read all the instruction before starting the project. </p>
# <p> You can finish entire project in this file, or you can use this file as guide and submit separated scripts</p>
# <h3> You can achieve maximum points (80) only on first exam period </h3>
# <p> Second Exam period is -5 points (1.25 points per LO) (max 75) </p>
# <p>  Third Exam period is -10 points (1.25 points per LO)(max 70) </p>
# <p>  Fourth Exam period is -15 points (1.25 points per LO) (max 65) </p>
#
#
# ---
#
#
# <h3> Project Points distribution (80 points in total) </h3>
# <table>
#     <thead>
#         <tr>
#             <th>Task</th>
#             <th>Points LO1</th>
#             <th>Points LO2</th>
#             <th>Points LO3</th>
#             <th>Points LO4</th>
#             <th>Total Points</th>
#             <th>Question Title</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Task 1</td>
#             <td>0.5</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>2.5</td>
#             <td>Task 1. Implement Hill-Climber Algorithm</td>
#         </tr>
#         <tr>
#             <td>Task 2</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>4</td>
#             <td>Task 2. Evaluate time complexity</td>
#         </tr>
#         <tr>
#             <td>Task 3</td>
#             <td>0.5</td>
#             <td>3</td>
#             <td>3</td>
#             <td>0</td>
#             <td>6.5</td>
#             <td>Task 3. Implement Simulated Annealing</td>
#         </tr>
#         <tr>
#             <td>Task 4</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>4</td>
#             <td>Task 4. Evaluate implemented temperature schedulers</td>
#         </tr>
#         <tr>
#             <td>Task 5</td>
#             <td>1</td>
#             <td>3</td>
#             <td>3</td>
#             <td>0</td>
#             <td>7</td>
#             <td>Task 5. Implement Particle Swarm Optimization algorithm</td>
#         </tr>
#         <tr>
#             <td>Task 6</td>
#             <td>0.5</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0.5</td>
#             <td>3</td>
#             <td>Task 6. Experiment with C1 and C2 hyperparameters</td>
#         </tr>
#         <tr>
#             <td>Task 7</td>
#             <td>0.5</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0.5</td>
#             <td>3</td>
#             <td>Task 7. Experiment with C1=0 and C2=1</td>
#         </tr>
#         <tr>
#             <td>Task 8</td>
#             <td>1</td>
#             <td>3</td>
#             <td>3</td>
#             <td>1</td>
#             <td>8</td>
#             <td>Task 8. Implement Ant Colony Optimization</td>
#         </tr>
#         <tr>
#             <td>Task 9</td>
#             <td>1</td>
#             <td>2</td>
#             <td>2</td>
#             <td>1</td>
#             <td>6</td>
#             <td>Task 9. Experiment with Ant Colony Optimization</td>
#         </tr>
#         <tr>
#             <td>Task 10</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>3</td>
#             <td>Task 10. Implement Genetic Algorithm (GA) Optimization</td>
#         </tr>
#         <tr>
#             <td>Task 11</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>4</td>
#             <td>Task 11. Experiment with Genetic Algorithm (GA) Optimization Hyperparameters</td>
#         </tr>
#         <tr>
#             <td>Task 12</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>2</td>
#             <td>Task 12. Use pyGAD library</td>
#         </tr>
#         <tr>
#             <td>Task 13</td>
#             <td>0</td>
#             <td>2</td>
#             <td>2</td>
#             <td>0</td>
#             <td>4</td>
#             <td>Task 13. The Needleman-Wunsch Algorithm</td>
#         </tr>
#         <tr>
#             <td>Task 14</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>2</td>
#             <td>Task 14. Time complexity of The Needleman-Wunsch Algorithm</td>
#         </tr>
#         <tr>
#             <td>Task 15</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>3</td>
#             <td>Task 15. Implement basic Gradient Descent</td>
#         </tr>
#         <tr>
#             <td>Task 16</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>4</td>
#             <td>Task 16. Experiment basic Gradient Descent</td>
#         </tr>
#         <tr>
#             <td>Task 17</td>
#             <td>1</td>
#             <td>2</td>
#             <td>2</td>
#             <td>1</td>
#             <td>6</td>
#             <td>Task 17. The end game - part 1</td>
#         </tr>
#         <tr>
#             <td>Task 18</td>
#             <td>1</td>
#             <td>3</td>
#             <td>3</td>
#             <td>1</td>
#             <td>8</td>
#             <td>Task 18. The end game - part 2</td>
#         </tr>
#         <tr>
#             <td><strong>Total Project Points</strong></td>
#             <td><strong>12</strong></td>
#             <td><strong>28</strong></td>
#             <td><strong>28</strong></td>
#             <td><strong>12</strong></td>
#             <td><strong>80</strong></td>
#             <td></td>
#         </tr>
#     </tbody>
# </table>
#
#
# ---
#
#
# <h3> Project Defense Tips: </h3>
#
# *   You do not have to use this file. You can have each task in separated file or 2 tasks in the same file, grouped by the topic. Up to you...
# *   You have to understand your code
# *   You have to be able to point to specific functionality of your code. For example, how do you compute acceptance probability? Point to function and explain
# *   You can answer on question by showing the plots you made. Make sure they are informative, because they will help you on project defense
# *   You have to use appropriate terminology, based on lectures and exercises.
# *   All algorithm implementations should work in multi-dimensional space even if example objective function is one-dimensional. The idea is that your implementation can work with any objective function.
#
#
# <h3> How will your project be graded? </h3>
#
# *   The solution that does not run will result with 0 points
# *   Within each task, read all the questions as they contribute to LO points
# *   If you do not understand your implementation, we will assume chatGPT (or other copy-pasting) which will result with disciplinary committee hearing

# %% [markdown]
# <h2>Task 1. Implement Hill-Climber Algorithm </h2> which is capable of solving N-dimensional problem. In the code block you can find example objective functions. Feel free to use any multi-dimensional objective function. The idea is that your implementation works the same for 1-dim and N-dim objective functions.

# %%
import numpy as np

def objective1(x):
    a = 1
    b = 100
    return (a - x[0]) ** 2 + b * (x[1] - x[0] ** 2) ** 2

def objective2(x):
    sum_part = sum(x_i ** 2 for x_i in x) / 4000
    product_part = np.prod(np.cos(x / np.sqrt(np.arange(1, len(x) + 1))))
    return 1 + sum_part - product_part

def hill_climber(objective_func, bounds, dimensions, max_iterations=1000, step_size=0.1):
    current = np.random.uniform(bounds[0], bounds[1], dimensions)
    current_value = objective_func(current)

    for iteration in range(max_iterations):
        neighbor = current + np.random.normal(0, step_size, dimensions)
        neighbor = np.clip(neighbor, bounds[0], bounds[1])
        neighbor_value = objective_func(neighbor)

        if neighbor_value < current_value:
            current = neighbor
            current_value = neighbor_value

    return current, current_value

x = np.array([0.2, 1.0, 23.3, 1.2, 2.5])
value = objective2(x)
print(f'objective2 function value at {x}: {value}')

x = np.array([1.2, 23.2])
value = objective1(x)
print(f'objective1 function value at {x}: {value}')

result1 = hill_climber(objective1, (-5, 5), 2)
print(f'Hill Climber on Rosenbrock: position={result1[0]}, value={result1[1]}')

result2 = hill_climber(objective2, (-5, 5), 1)
print(f'Hill Climber on Griewank: position={result2[0]}, value={result2[1]}')
# Out:
# objective2 function value at [ 0.2  1.  23.3  1.2  2.5]: 0.9677290088723365
# objective1 function value at [ 1.2 23.2]: 47349.799999999996
# Hill Climber on Rosenbrock: position=[0.99188573 0.98100665], value=0.0008670969073596591
# Hill Climber on Griewank: position=[-6.97285367e-05], value=2.4322498459738995e-09

# %% [markdown]
# <h2> Task 2. Evaluate time complexity</h2> of your Hill-Climber implementation. This include varying the input size from, for example, 1 to 10000 ( you might need more) and record the running time each time. You can use this implementation for all time complexity evaluations later in the project. This should result in a similar table: <br>
# <h2 style="text-align: center;">Time Complexity Evaluation Table</h2>
# <table>
#     <tr>
#         <th>input_size_max_iter</th>
#         <th>input_size_local_search</th>
#         <th>time_max_iter (s)</th>
#         <th>time_local_search (s)</th>
#         <th>total_time (s)</th>
#     </tr>
#     <tr>
#         <td>100</td>
#         <td>50</td>
#         <td>0.12</td>
#         <td>0.05</td>
#         <td>0.17</td>
#     </tr>
#     <tr>
#         <td>200</td>
#         <td>100</td>
#         <td>0.25</td>
#         <td>0.09</td>
#         <td>0.34</td>
#     </tr>
#     <tr>
#         <td>300</td>
#         <td>150</td>
#         <td>0.38</td>
#         <td>0.12</td>
#         <td>0.50</td>
#     </tr>
#     <tr>
#         <td>400</td>
#         <td>200</td>
#         <td>0.51</td>
#         <td>0.15</td>
#         <td>0.66</td>
#     </tr>
#     <tr>
#         <td>500</td>
#         <td>250</td>
#         <td>0.70</td>
#         <td>0.19</td>
#         <td>0.89</td>
#     </tr>
#     <tr>
#         <td>600</td>
#         <td>300</td>
#         <td>0.85</td>
#         <td>0.24</td>
#         <td>1.09</td>
#     </tr>
#     <tr><td>....</td></tr>
# </table>
# Create line plots indicating O(m*n) time complexity, where m is max iter and n is local search iteration. You can compute "growth rate" of time between each i-th and i-1-th iteration and prove they are increased by m*n

# %%
import time
import matplotlib.pyplot as plt

print("max_iter | dimensions | total_time (s) | time_per_iter (s) | time_per_eval (s)")
print("-" * 80)

test_cases = [(100, 50), (200, 100), (500, 250), (1000, 500), (2000, 1000), (5000, 2500)]
times, m_n_values, times_per_iter, times_per_eval = [], [], [], []

for max_iter, dimensions in test_cases:
    start_time = time.time()
    hill_climber(objective2, (-5, 5), dimensions, max_iterations=max_iter)
    total_time = time.time() - start_time

    time_per_iteration = total_time / max_iter
    time_per_evaluation = total_time / (max_iter * dimensions)

    print(
        f"{max_iter:8} | {dimensions:10} | {total_time:12.4f} | {time_per_iteration:13.6f} | {time_per_evaluation:12.8f}")

    times.append(total_time)
    m_n_values.append(max_iter * dimensions)
    times_per_iter.append(time_per_iteration)
    times_per_eval.append(time_per_evaluation)

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(m_n_values, times, 'o-')
plt.xlabel('m × n')
plt.ylabel('Total Time (s)')
plt.title('Total Time vs m×n')

plt.subplot(1, 3, 2)
plt.plot([tc[0] for tc in test_cases], times_per_iter, 'o-', color='green')
plt.xlabel('Max Iterations')
plt.ylabel('Time per Iteration (s)')
plt.title('Time per Iteration')

plt.subplot(1, 3, 3)
plt.plot(m_n_values, times_per_eval, 'o-', color='red')
plt.xlabel('m × n')
plt.ylabel('Time per Evaluation (s)')
plt.title('Time per Function Evaluation')

plt.tight_layout()
plt.show()
# Out:
# max_iter | dimensions | total_time (s) | time_per_iter (s) | time_per_eval (s)
# --------------------------------------------------------------------------------
#      100 |         50 |       0.0029 |      0.000029 |   0.00000057
#      200 |        100 |       0.0037 |      0.000018 |   0.00000018
#      500 |        250 |       0.0168 |      0.000034 |   0.00000013
#     1000 |        500 |       0.0600 |      0.000060 |   0.00000012
#     2000 |       1000 |       0.2356 |      0.000118 |   0.00000012
#     5000 |       2500 |       1.3722 |      0.000274 |   0.00000011

# %% [markdown]
# <h2> Task 3. Implement Simulated Annealing </h2> with following options for "cooling" the temperature:
#
# *   Linear Cooling Schedule: Tk = T0 − α⋅k, where T0 is initial temperature, α is a constant and k is iteration number.
# *   Logarithmic Cooling Schedule: Tk = (T0)/(log(k+1)), where T0 is initial temperature and k is iteration number
# *   Exponential Cooling Schedule: Tk = T0 ⋅ B^k, where T0 is initial temperature, k is iteration number and 0 < β < 1 is cooling rate
# *   Adaptive Cooling Schedule: An adaptive temperature schedule adjusts the cooling rate based on the algorithm's performance, such as the acceptance rate of new solutions. The idea is to slow down the cooling process if the algorithm is still finding better solutions and to speed it up if the algorithm is stagnating
# *   Custom cooling schedule: A custom temperature schedule can be designed to fit specific problem characteristics or based on empirical observations. Get creative in this one. It does not have to work better, but have an explanation of your idea.

# %%
import numpy as np
import matplotlib.pyplot as plt


def simulated_annealing(objective_func, bounds, dimensions, max_iterations=1000,
                        initial_temp=100, cooling_schedule='exponential',
                        alpha=0.1, beta=0.99, step_size=0.1):
    current = np.random.uniform(bounds[0], bounds[1], dimensions)
    current_value = objective_func(current)
    best = current.copy()
    best_value = current_value

    acceptance_count = 0
    check_interval = 50

    for k in range(max_iterations):
        neighbor = current + np.random.normal(0, step_size, dimensions)
        neighbor = np.clip(neighbor, bounds[0], bounds[1])
        neighbor_value = objective_func(neighbor)

        if cooling_schedule == 'linear':
            temperature = max(0.01, initial_temp - alpha * k)
        elif cooling_schedule == 'logarithmic':
            temperature = initial_temp / np.log(k + 2)
        elif cooling_schedule == 'exponential':
            temperature = initial_temp * (beta ** k)
        elif cooling_schedule == 'adaptive':
            if k > 0 and k % check_interval == 0:
                acceptance_rate = acceptance_count / check_interval
                if acceptance_rate > 0.3:
                    beta = 0.995
                elif acceptance_rate < 0.1:
                    beta = 0.95
                else:
                    beta = 0.99
                acceptance_count = 0
            temperature = initial_temp * (beta ** k)
        elif cooling_schedule == 'custom':
            wave = 0.3 * np.sin(2 * np.pi * k / 100)
            temperature = initial_temp * (beta ** k) * (1 + wave)

        if neighbor_value < current_value:
            current = neighbor
            current_value = neighbor_value
            if cooling_schedule == 'adaptive':
                acceptance_count += 1
        else:
            delta = neighbor_value - current_value
            probability = np.exp(-delta / temperature) if temperature > 0 else 0
            if np.random.random() < probability:
                current = neighbor
                current_value = neighbor_value
                if cooling_schedule == 'adaptive':
                    acceptance_count += 1

        if current_value < best_value:
            best = current.copy()
            best_value = current_value

    return best, best_value


schedules = ['linear', 'logarithmic', 'exponential', 'adaptive', 'custom']
results = {}

print("Simulated Annealing Results:")
print("=" * 60)

for schedule in schedules:
    solution, value = simulated_annealing(objective2, (-5, 5), 5,
                                          max_iterations=2000,
                                          cooling_schedule=schedule)
    results[schedule] = (solution, value)
    print(f"{schedule.upper():12} | value={value:.6f} | position={solution}")

print("=" * 60)

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
iterations = np.arange(1000)
for schedule in ['linear', 'logarithmic', 'exponential']:
    temps = []
    for k in iterations:
        if schedule == 'linear':
            temp = max(0.01, 100 - 0.1 * k)
        elif schedule == 'logarithmic':
            temp = 100 / np.log(k + 2)
        elif schedule == 'exponential':
            temp = 100 * (0.99 ** k)
        temps.append(temp)
    plt.plot(iterations, temps, label=schedule.title())
plt.xlabel('Iterations')
plt.ylabel('Temperature')
plt.title('Cooling Schedules Comparison')
plt.legend()
plt.yscale('log')

plt.subplot(2, 2, 2)
schedule_names = list(results.keys())
values = [results[s][1] for s in schedule_names]
colors = ['red', 'blue', 'green', 'orange', 'purple']
bars = plt.bar(schedule_names, values, color=colors, alpha=0.7)
plt.xlabel('Cooling Schedule')
plt.ylabel('Final Objective Value')
plt.title('Performance Comparison')
plt.xticks(rotation=45)

for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
             f'{value:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# Simulated Annealing Results:
# ============================================================
# LINEAR       | value=0.515896 | position=[-3.02322249 -4.31405477  0.93543652 -0.6511064   2.03762176]
# LOGARITHMIC  | value=0.160423 | position=[-3.21673348  4.58968695 -0.1793573   0.0966393  -1.19569112]
# EXPONENTIAL  | value=0.043543 | position=[ 0.01076152 -4.43911559 -5.         -0.00695257 -0.0065276 ]
# ADAPTIVE     | value=0.392437 | position=[-3.11789416e+00  7.39990315e-02  1.60552097e-03  1.13455141e-02
#  -5.00000000e+00]
# CUSTOM       | value=0.391669 | position=[-3.14222886e+00  3.73634310e-02  8.62858024e-03  1.44128393e-03
#  -5.00000000e+00]
# ============================================================

# %% [markdown]
# <h2> Task 4. Evaluate implemented temperature schedulers </h2>  in terms of:
#
# *   Exploration vs. Exploitation: if the cooling schedule is too aggressive, the algorithm may converge prematurely, settling in local minima instead of finding the global minimum
# *   Convergence Speed: well-tuned cooling schedule can significantly reduce the number of iterations required to converge to a good solution.
# *   Quality of Solutions: A gradual cooling schedule tends to yield better quality solutions since it allows the algorithm to explore the solution space longer before committing to a particular region.
#
# Define Metrics for Evaluation:
# *   Exploration vs. Exploitation: Measure the acceptance rate of worse solutions over iterations
# *   Convergence Speed: Track the number of iterations taken to reach a solution within a predefined tolerance
# *   Quality of Solutions: Compare the final solution obtained by different temperature schedulers to the known optimal or global minimum value
# *   Report hyperparameters which will make SA never converge. Why?
#
# <p> Use Rastrigin function  as objective function for evaluation. Google how it looks, it is a function with a lot of local minima and only one global minima. You will have to run each setup multiple times. Create a table with results, visualize it using boxplots (for example). Compare mean values of metrics and based on that draw conclusions. </p>
# <img src="https://upload.wikimedia.org/wikipedia/commons/8/8b/Rastrigin_function.png" alt="Example Image" width="300" height="200">

# %%
import numpy as np
import matplotlib.pyplot as plt
import time


def rastrigin(x):
    A = 10
    n = len(x)
    return A * n + sum(x_i ** 2 - A * np.cos(2 * np.pi * x_i) for x_i in x)


def simulated_annealing_metrics(objective_func, bounds, dimensions, max_iterations=1000,
                                initial_temp=100, cooling_schedule='exponential',
                                alpha=0.1, beta=0.99, step_size=0.1):
    current = np.random.uniform(bounds[0], bounds[1], dimensions)
    current_value = objective_func(current)
    best = current.copy()
    best_value = current_value

    worse_accepted = 0
    convergence_iter = max_iterations
    check_interval = 50
    acceptance_count = 0

    for k in range(max_iterations):
        neighbor = current + np.random.normal(0, step_size, dimensions)
        neighbor = np.clip(neighbor, bounds[0], bounds[1])
        neighbor_value = objective_func(neighbor)

        if cooling_schedule == 'linear':
            temperature = max(0.01, initial_temp - alpha * k)
        elif cooling_schedule == 'logarithmic':
            temperature = initial_temp / np.log(k + 2)
        elif cooling_schedule == 'exponential':
            temperature = initial_temp * (beta ** k)
        elif cooling_schedule == 'adaptive':
            if k > 0 and k % check_interval == 0:
                acceptance_rate = acceptance_count / check_interval
                if acceptance_rate > 0.3:
                    beta = 0.995
                elif acceptance_rate < 0.1:
                    beta = 0.95
                else:
                    beta = 0.99
                acceptance_count = 0
            temperature = initial_temp * (beta ** k)
        elif cooling_schedule == 'custom':
            wave = 0.3 * np.sin(2 * np.pi * k / 100)
            temperature = initial_temp * (beta ** k) * (1 + wave)

        if neighbor_value < current_value:
            current = neighbor
            current_value = neighbor_value
            if cooling_schedule == 'adaptive':
                acceptance_count += 1
        else:
            delta = neighbor_value - current_value
            probability = np.exp(-delta / temperature) if temperature > 0 else 0
            if np.random.random() < probability:
                current = neighbor
                current_value = neighbor_value
                worse_accepted += 1
                if cooling_schedule == 'adaptive':
                    acceptance_count += 1

        if current_value < best_value:
            best = current.copy()
            best_value = current_value
            if best_value < 0.1 and convergence_iter == max_iterations:
                convergence_iter = k

    exploration_rate = worse_accepted / max_iterations
    return best, best_value, exploration_rate, convergence_iter


schedules = ['linear', 'logarithmic', 'exponential', 'adaptive', 'custom']
num_trials = 30
results = {schedule: {'quality': [], 'convergence': [], 'exploration': []} for schedule in schedules}

for schedule in schedules:
    for trial in range(num_trials):
        start_time = time.time()
        _, quality, exploration, convergence = simulated_annealing_metrics(
            rastrigin, (-5.12, 5.12), 2, max_iterations=1000, cooling_schedule=schedule
        )
        execution_time = time.time() - start_time

        results[schedule]['quality'].append(quality)
        results[schedule]['convergence'].append(convergence)
        results[schedule]['exploration'].append(exploration)

print("Schedule | Mean Quality | Convergence Speed | Exploration Rate")
print("-" * 65)
for schedule in schedules:
    mean_quality = np.mean(results[schedule]['quality'])
    mean_convergence = np.mean(results[schedule]['convergence'])
    mean_exploration = np.mean(results[schedule]['exploration'])
    print(f"{schedule:12} | {mean_quality:11.3f} | {mean_convergence:15.1f} | {mean_exploration:12.3f}")

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
quality_data = [results[s]['quality'] for s in schedules]
plt.boxplot(quality_data, tick_labels=schedules)
plt.ylabel('Final Objective Value')
plt.title('Quality of Solutions')
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
convergence_data = [results[s]['convergence'] for s in schedules]
plt.boxplot(convergence_data, tick_labels=schedules)
plt.ylabel('Iterations to Convergence')
plt.title('Convergence Speed')
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
exploration_data = [results[s]['exploration'] for s in schedules]
plt.boxplot(exploration_data, tick_labels=schedules)
plt.ylabel('Worse Acceptance Rate')
plt.title('Exploration vs Exploitation')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Schedule | Mean Quality | Convergence Speed | Exploration Rate
# -----------------------------------------------------------------
# linear       |       6.606 |          1000.0 |        0.452
# logarithmic  |       7.357 |           969.1 |        0.430
# exponential  |      12.074 |          1000.0 |        0.185
# adaptive     |      10.114 |          1000.0 |        0.336
# custom       |      12.115 |          1000.0 |        0.185

# %% [markdown]
# <h2> Task 5. Implement Particle Swarm Optimization algorithm </h2>
# Select a multidimensional function to optimize (e.g., Rosenbrock function, Rastrigin function, or Griewank function).
#
#
# 1.  Define a class for the particle that includes properties such as position, velocity, personal best position, and personal best value.
# 2.  Initialize a swarm of particles with random positions and velocities within defined boundaries.
# 3.  Implement PSO formula for position update
# 4.  Create a running loop, which perform the optimization

# %%
import numpy as np
import matplotlib.pyplot as plt


def rastrigin(x):
    A = 10
    n = len(x)
    return A * n + sum(x_i ** 2 - A * np.cos(2 * np.pi * x_i) for x_i in x)


class Particle:
    def __init__(self, dimensions, bounds):
        self.position = np.random.uniform(bounds[0], bounds[1], dimensions)
        self.velocity = np.random.uniform(-1, 1, dimensions)
        self.best_position = self.position.copy()
        self.best_value = float('inf')

    def evaluate(self, objective_func):
        current_value = objective_func(self.position)
        if current_value < self.best_value:
            self.best_value = current_value
            self.best_position = self.position.copy()
        return current_value

    def update_velocity(self, global_best_position, w, c1, c2):
        r1, r2 = np.random.random(len(self.position)), np.random.random(len(self.position))
        cognitive = c1 * r1 * (self.best_position - self.position)
        social = c2 * r2 * (global_best_position - self.position)
        self.velocity = w * self.velocity + cognitive + social

    def update_position(self, bounds):
        self.position += self.velocity
        self.position = np.clip(self.position, bounds[0], bounds[1])


def particle_swarm_optimization(objective_func, bounds, dimensions, num_particles=30,
                                max_iterations=1000, w=0.7, c1=2.0, c2=2.0):
    swarm = [Particle(dimensions, bounds) for _ in range(num_particles)]

    global_best_value = float('inf')
    global_best_position = None
    history = []

    for iteration in range(max_iterations):
        for particle in swarm:
            current_value = particle.evaluate(objective_func)

            if current_value < global_best_value:
                global_best_value = current_value
                global_best_position = particle.position.copy()

        for particle in swarm:
            particle.update_velocity(global_best_position, w, c1, c2)
            particle.update_position(bounds)

        history.append(global_best_value)

    return global_best_position, global_best_value, history


best_position, best_value, history = particle_swarm_optimization(
    rastrigin, (-5.12, 5.12), 2, num_particles=30, max_iterations=500
)

print(f"Best position: {best_position}")
print(f"Best value: {best_value:.6f}")

plt.figure(figsize=(8, 4))
plt.plot(history)
plt.xlabel('Iterations')
plt.ylabel('Best Objective Value')
plt.title('PSO Convergence')
plt.grid(True)
plt.show()
# Out:
# Best position: [ 9.67577784e-10 -2.70949996e-09]
# Best value: 0.000000

# %% [markdown]
# <h2> Task 6. Experiment with C1 and C2 hyperparameters </h2>
# The goal of this project is to investigate the effects of the cognitive coefficient (c1) social coefficient (c2) and inertia weight (w) on the convergence behavior of the Particle Swarm Optimization algorithm.
#
#
# 1.   Ensure that you have a working implementation of PSO (Task 5)
# 2.   Conduct Experiments:
#
# * For each combination of c1,c2 and w, run the PSO algorithm multiple times (e.g., 30 runs) to account for randomness and obtain average results
# * Vary the hyperparameters c1, c2, w: Track and record the following metrics for each configuration (Best solution found, Number of iterations to convergence, Average time taken per run)
# * Create plots to visualize convergence speeds and best solutions over iterations for different parameter settings
#
# <p> 3.) Report hyperparameters which will make PSO never converge. Why?</p>

# %%
import time

def pso_with_metrics(objective_func, bounds, dimensions, w, c1, c2, num_particles=30, max_iterations=500):
    swarm = [Particle(dimensions, bounds) for _ in range(num_particles)]

    global_best_value = float('inf')
    global_best_position = None
    convergence_iter = max_iterations

    for iteration in range(max_iterations):
        for particle in swarm:
            current_value = particle.evaluate(objective_func)

            if current_value < global_best_value:
                global_best_value = current_value
                global_best_position = particle.position.copy()

        for particle in swarm:
            particle.update_velocity(global_best_position, w, c1, c2)
            particle.update_position(bounds)

        if global_best_value < 0.1 and convergence_iter == max_iterations:
            convergence_iter = iteration

    return global_best_value, convergence_iter

w_values = [0.3, 0.7, 0.9]
c1_values = [0.5, 1.5, 2.5]
c2_values = [0.5, 1.5, 2.5]
num_trials = 30

results = {}
all_configs = []

for w in w_values:
    for c1 in c1_values:
        for c2 in c2_values:
            config = f'w={w}, c1={c1}, c2={c2}'
            all_configs.append((w, c1, c2, config))
            results[config] = {'quality': [], 'convergence': [], 'time': []}

for w, c1, c2, config in all_configs:
    for trial in range(num_trials):
        start_time = time.time()
        quality, convergence = pso_with_metrics(rastrigin, (-5.12, 5.12), 2, w, c1, c2)
        execution_time = time.time() - start_time

        results[config]['quality'].append(quality)
        results[config]['convergence'].append(convergence)
        results[config]['time'].append(execution_time)

best_config = min(all_configs, key=lambda x: np.mean(results[x[3]]['quality']))
worst_config = max(all_configs, key=lambda x: np.mean(results[x[3]]['quality']))

print(f"Best: {best_config[3]} | Quality: {np.mean(results[best_config[3]]['quality']):.3f}")
print(f"Worst: {worst_config[3]} | Quality: {np.mean(results[worst_config[3]]['quality']):.3f}")

best_configs = sorted(all_configs[:6], key=lambda x: np.mean(results[x[3]]['quality']))
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
quality_data = [results[config[3]]['quality'] for config in best_configs]
labels = [f'w={c[0]}\nc1={c[1]}\nc2={c[2]}' for c in best_configs]
plt.boxplot(quality_data, tick_labels=labels)
plt.ylabel('Best Quality')
plt.title('Solution Quality')

plt.subplot(1, 3, 2)
convergence_data = [results[config[3]]['convergence'] for config in best_configs]
plt.boxplot(convergence_data, tick_labels=labels)
plt.ylabel('Iterations to Convergence')
plt.title('Convergence Speed')

plt.subplot(1, 3, 3)
time_data = [results[config[3]]['time'] for config in best_configs]
plt.boxplot(time_data, tick_labels=labels)
plt.ylabel('Execution Time (s)')
plt.title('Average Time per Run')

plt.tight_layout()
plt.show()

print("\nHyperparameters that prevent convergence:")
print("- Very high w (w > 1.0): particles never slow down, oscillate forever")
print("- c1 + c2 > 4: unstable system, explosive behavior")
print("- c1 = c2 = 0: no guidance, random walk")
# Out:
# Best: w=0.3, c1=2.5, c2=1.5 | Quality: 0.000
# Worst: w=0.3, c1=0.5, c2=1.5 | Quality: 0.929
# Hyperparameters that prevent convergence:
# - Very high w (w > 1.0): particles never slow down, oscillate forever
# - c1 + c2 > 4: unstable system, explosive behavior
# - c1 = c2 = 0: no guidance, random walk

# %% [markdown]
# <h2> Task 7. Experiment with C1=0 and C2=1 </h2>
# <p> Fix other hyperparemeters to meaningful values and use c1=0 and c2=1 </p>
# <p> How does PSO behave? Is this reminding you of other algorithm? Why? </p>

# %%
w, c1, c2 = 0.7, 0, 1
num_particles, max_iterations = 30, 500

best_value, best_position, convergence_history = particle_swarm_optimization(
    rastrigin, (-5.12, 5.12), 2, num_particles, max_iterations, w, c1, c2
)

print(f"Best position: {best_position}")
print(f"Best value: {best_value}")

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(convergence_history)
plt.xlabel('Iterations')
plt.ylabel('Best Objective Value')
plt.title('PSO Convergence (c1=0, c2=1)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(convergence_history[:100])
plt.xlabel('Iterations')
plt.ylabel('Best Objective Value')
plt.title('First 100 Iterations')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Best position: 0.0
# Best value: [-3.44175121e-09 -6.51548169e-10]

# %% [markdown]
# Explain your results:With c1=0, c2=1, particles don't consider their own experience but all move toward wherever any particle reports a better solution. This essentially becomes like hill climber because it behaves as if one single particle is moving forward until it finds the optimal solution.

# %% [markdown]
# <h2> Task 8. Implement Ant Colony Optimization </h2>
# Use the Traveling Salesman Problem (TSP) as the objective function for this task. The TSP is a classic optimization problem where the goal is to find the shortest possible route that visits each city exactly once and returns to the origin city.
# <p>Objective Function: For a given set of cities and their pairwise distances, the objective function can be defined as sum of all distances or f(x)=Total Distance of the Route</p>
#
# 1.   Define the number of ants, the pheromone matrix, and the heuristic information (usually the inverse of the distance)
# 2.   Implement a pheromone update rule that allows pheromones to evaporate over time and be deposited by ants based on the quality of the solution found
# 3.   Define how ants choose their next city based on pheromone levels and heuristic information (using a probability-based approach)
# 4.   Finish the implementation and create loop which optimizes the objective function

# %%
import numpy as np

distance_matrix = np.array([
    [0, 3.16, 4.00, 6.08, 3.00],
    [3.16, 0, 3.00, 5.10, 3.16],
    [4.00, 3.00, 0, 3.16, 1.00],
    [6.08, 5.10, 3.16, 0, 3.16],
    [3.00, 3.16, 1.00, 3.16, 0]
])

cities = ['A', 'B', 'C', 'D', 'E']


def calculate_tour_distance(tour, distance_matrix):
    distance = 0
    for i in range(len(tour)):
        distance += distance_matrix[tour[i]][tour[(i + 1) % len(tour)]]
    return distance


def construct_ant_tour(pheromones, heuristic, alpha, beta, num_cities):
    tour = [0]
    unvisited = set(range(1, num_cities))

    while unvisited:
        current_city = tour[-1]
        probabilities = []

        for city in unvisited:
            prob = (pheromones[current_city][city] ** alpha) * (heuristic[current_city][city] ** beta)
            probabilities.append(prob)

        probabilities = np.array(probabilities)
        probabilities /= probabilities.sum()

        next_city_idx = np.random.choice(len(probabilities), p=probabilities)
        next_city = list(unvisited)[next_city_idx]

        tour.append(next_city)
        unvisited.remove(next_city)

    return tour


def ant_colony_optimization(distance_matrix, num_ants=10, num_iterations=100,
                            alpha=1.0, beta=2.0, evaporation_rate=0.5, Q=1.0):
    num_cities = len(distance_matrix)
    pheromones = np.ones((num_cities, num_cities))
    heuristic = 1.0 / (distance_matrix + 1e-10)

    best_tour = None
    best_distance = float('inf')

    for iteration in range(num_iterations):
        tours = []
        distances = []

        for ant in range(num_ants):
            tour = construct_ant_tour(pheromones, heuristic, alpha, beta, num_cities)
            distance = calculate_tour_distance(tour, distance_matrix)
            tours.append(tour)
            distances.append(distance)

            if distance < best_distance:
                best_distance = distance
                best_tour = tour.copy()

        pheromones *= (1 - evaporation_rate)

        for tour, distance in zip(tours, distances):
            pheromone_deposit = Q / distance
            for i in range(len(tour)):
                from_city = tour[i]
                to_city = tour[(i + 1) % len(tour)]
                pheromones[from_city][to_city] += pheromone_deposit
                pheromones[to_city][from_city] += pheromone_deposit

    return best_tour, best_distance


best_tour, best_distance = ant_colony_optimization(distance_matrix)

print(f"Best tour: {[cities[i] for i in best_tour]}")
print(f"Best distance: {best_distance:.2f}")
# Out:
# Best tour: ['A', 'B', 'D', 'C', 'E']
# Best distance: 15.42

# %% [markdown]
# <h2> Task 9. Experiment with Ant Colony Optimization </h2>
# Experiment with:
#
#
# *   Pheromone Importance (α): Controls the influence of pheromone on the decision-making process.
# *   Heuristic Importance (β): Controls the influence of the heuristic information (e.g., distance).
# *   Pheromone Evaporation Rate (𝜌): Determines how quickly pheromone evaporates over time.
# *   Number of Ants: The size of the ant population.
#
# <p> 1.)Run the ACO algorithm with different combinations of α,β, 𝜌, and the number of ants. For each combination, record the best tour found and the total distance. Conduct multiple trials (e.g., 30 runs) for each parameter combination to obtain reliable average results. </p>
# <p> 2.) Create plots to illustrate how changing the hyperparameters affects performance. Write a report summarizing the findings in you see in plots. </p>
# <p> 3.) What is the time complexity of Ant colony Optimization? Why? You do not have to create plots (but if you want, use previously defined approach) </p>
# <p> 4.) Report hyperparameters which will make Ant colony never converge. Why?</p>

# %%
import time
import matplotlib.pyplot as plt


def aco_with_metrics(distance_matrix, alpha, beta, evaporation_rate, num_ants):
    best_tour, best_distance = ant_colony_optimization(
        distance_matrix, num_ants=num_ants, num_iterations=100,
        alpha=alpha, beta=beta, evaporation_rate=evaporation_rate
    )
    return best_distance


alpha_values = [0.5, 1.0, 2.0]
beta_values = [1.0, 2.0, 3.0]
rho_values = [0.1, 0.5, 0.9]
ant_values = [5, 10, 20]
num_trials = 30

results = {}
all_configs = []

for alpha in alpha_values:
    for beta in beta_values:
        for rho in rho_values:
            for ants in ant_values:
                config = f'α={alpha}, β={beta}, ρ={rho}, ants={ants}'
                all_configs.append((alpha, beta, rho, ants, config))
                results[config] = {'distance': [], 'time': []}

tested_configs = all_configs[:12]

for alpha, beta, rho, ants, config in tested_configs:
    for trial in range(num_trials):
        start_time = time.time()
        distance = aco_with_metrics(distance_matrix, alpha, beta, rho, ants)
        execution_time = time.time() - start_time

        results[config]['distance'].append(distance)
        results[config]['time'].append(execution_time)

top_50_percent = len(tested_configs) // 2

plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
distance_configs = sorted(tested_configs, key=lambda x: np.mean(results[x[4]]['distance']))[:top_50_percent]
distance_data = [results[config[4]]['distance'] for config in distance_configs]
distance_labels = [f'α={c[0]},β={c[1]}\nρ={c[2]},ants={c[3]}' for c in distance_configs]
plt.boxplot(distance_data, tick_labels=distance_labels)
plt.ylabel('Best Distance')
plt.title('Solution Quality (Top 50%)')

plt.subplot(1, 3, 2)
time_configs = sorted(tested_configs, key=lambda x: np.mean(results[x[4]]['time']))[:top_50_percent]
time_data = [results[config[4]]['time'] for config in time_configs]
time_labels = [f'α={c[0]},β={c[1]}\nρ={c[2]},ants={c[3]}' for c in time_configs]
plt.boxplot(time_data, tick_labels=time_labels)
plt.ylabel('Execution Time (s)')
plt.title('Average Time per Run (Top 50%)')

plt.subplot(1, 3, 3)
ant_counts = [5, 10, 15, 20, 25]
times = []
for ants in ant_counts:
    start_time = time.time()
    aco_with_metrics(distance_matrix, 1.0, 2.0, 0.5, ants)
    times.append(time.time() - start_time)

plt.plot(ant_counts, times, 'o-')
plt.xlabel('Number of Ants')
plt.ylabel('Execution Time (s)')
plt.title('Time Complexity O(A×N²)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ρ = 1.0: If ρ = 1.0, all pheromones evaporate completely after each iteration. The colony has total amnesia and cannot learn from previous steps, making the search inefficient.
#
# α = 0 and β = 0: If both are 0, ants are 'blind' - they don't see pheromones (α=0) nor distances (β=0). They choose cities randomly as if rolling a die.
#
# ρ = 0.0: If ρ = 0.0, pheromones never evaporate and accumulate forever. The first decent route becomes so 'strong' that ants will "fall in love" with it and stop exploring other options.

# %% [markdown]
# <h2> Task 10. Implement Genetic Algorithm (GA) Optimization </h2>
# The goal of this task is to implement a Genetic Algorithm to solve an optimization problem. GA can optimize continuous (numeric) and discrete (categorical) problems. For example
#
# *   Rastrigin, an example of continous objective function you have implemented above. But use at least 10 dimnesions. Check code bellow.
# *   Knapsack Problem, the Knapsack Problem is a classic optimization problem where the goal is to maximize the total value of items that can be placed into a knapsack without exceeding its weight capacity
#
# <p>Let's start with implementation</p>
#
# 1.   Implement a selection mechanisms: tournament selection, roulette wheel selection. Their purpose is to choose individuals based on their fitness values
# 2.   Implement crossover techniques to combine the genetic information of two parent individuals to create offspring. Implement, single-point crossover, 2-point crossover and uniform crossover.
# 3.   Implement mutation: Introduce random mutations in offspring to maintain genetic diversity. Implement gaussian mutation for numeric problems and implement Flip-bit mutation for discrete problems.
# 4.   Create a main loop which performs the optimization
# 5.   Create an inner loop which creates new population based on current population
# 6.   Create encoding for Knapsack problem. For example, knapsack containing only first item (out of 4) will be encoded as [1,0,0,0]. Knapsack containing second and fourth item will be encoded as [0,1,0,1], etc...
# 7. Finish the fitness function for Knapsack problem
# 8. Run on both problems and get results

# %%
import numpy as np


def rastrigin_high_dimen(x):
    A = 10
    n = len(x)
    if n < 10:
        return -1
    else:
        return A * n + sum(x_i ** 2 - A * np.cos(2 * np.pi * x_i) for x_i in x)


def tournament_selection(population, fitness_scores):
    selected = []
    for _ in range(len(population)):
        tournament = np.random.choice(len(population), 3, replace=False)
        winner = tournament[np.argmax([fitness_scores[i] for i in tournament])]
        selected.append(population[winner].copy())
    return selected


def roulette_wheel_selection(population, fitness_scores):
    fitness_scores = np.array(fitness_scores)
    fitness_scores = fitness_scores - np.min(fitness_scores) + 1
    probabilities = fitness_scores / np.sum(fitness_scores)
    indices = np.random.choice(len(population), len(population), p=probabilities)
    return [population[i].copy() for i in indices]


def single_point_crossover(parent1, parent2):
    point = np.random.randint(1, len(parent1))
    child1 = np.concatenate([parent1[:point], parent2[point:]])
    child2 = np.concatenate([parent2[:point], parent1[point:]])
    return child1, child2


def two_point_crossover(parent1, parent2):
    points = sorted(np.random.choice(range(1, len(parent1)), 2, replace=False))
    child1 = np.concatenate([parent1[:points[0]], parent2[points[0]:points[1]], parent1[points[1]:]])
    child2 = np.concatenate([parent2[:points[0]], parent1[points[0]:points[1]], parent2[points[1]:]])
    return child1, child2


def uniform_crossover(parent1, parent2):
    mask = np.random.random(len(parent1)) < 0.5
    child1 = np.where(mask, parent1, parent2)
    child2 = np.where(mask, parent2, parent1)
    return child1, child2


def gaussian_mutation(individual, rate=0.1):
    for i in range(len(individual)):
        if np.random.random() < rate:
            individual[i] += np.random.normal(0, 0.5)
    return individual


def flip_bit_mutation(individual, rate=0.1):
    for i in range(len(individual)):
        if np.random.random() < rate:
            individual[i] = 1 - individual[i]
    return individual


population = [np.random.uniform(-5, 5, 12) for _ in range(50)]

for generation in range(100):
    fitness_scores = [-rastrigin_high_dimen(ind) for ind in population]

    selected = tournament_selection(population, fitness_scores)

    new_population = []
    for i in range(0, len(selected), 2):
        parent1, parent2 = selected[i], selected[i + 1] if i + 1 < len(selected) else selected[0]
        child1, child2 = single_point_crossover(parent1, parent2)
        new_population.extend([gaussian_mutation(child1), gaussian_mutation(child2)])

    population = new_population[:50]

best_rastrigin = population[np.argmax([-rastrigin_high_dimen(ind) for ind in population])]
print(f"Rastrigin result: {-rastrigin_high_dimen(best_rastrigin)}")

x = np.array([1.2, 2.3, 20, 3, 3.2, 5.4, 42.1, 2, 1, 2, 4, 5])
value = rastrigin_high_dimen(x)
print(f'Rastrigin function value at {x}: {value}')
# Out:
# Rastrigin result: -15.862182952162641
# Rastrigin function value at [ 1.2  2.3 20.   3.   3.2  5.4 42.1  2.   1.   2.   4.   5. ]: 2324.4498300562504

# %%
knapsack_items = {
    'item1': {'value': 60, 'weight': 10},
    'item2': {'value': 100, 'weight': 20},
    'item3': {'value': 120, 'weight': 30},
    'item4': {'value': 80, 'weight': 15},
    'item5': {'value': 40, 'weight': 5},
    'item6': {'value': 70, 'weight': 25},
    'item7': {'value': 90, 'weight': 35},
    'item8': {'value': 150, 'weight': 40},
    'item9': {'value': 200, 'weight': 50},
    'item10': {'value': 30, 'weight': 10}
}

capacity = 100


def fitness(individual):
    items_list = list(knapsack_items.values())
    total_value = sum(individual[i] * items_list[i]['value'] for i in range(len(individual)))
    total_weight = sum(individual[i] * items_list[i]['weight'] for i in range(len(individual)))

    if total_weight > capacity:
        return 0
    return total_value


population = [np.random.randint(0, 2, 10) for _ in range(50)]

for generation in range(100):
    fitness_scores = [fitness(ind) for ind in population]

    selected = roulette_wheel_selection(population, fitness_scores)

    new_population = []
    for i in range(0, len(selected), 2):
        parent1, parent2 = selected[i], selected[i + 1] if i + 1 < len(selected) else selected[0]
        child1, child2 = uniform_crossover(parent1, parent2)
        new_population.extend([flip_bit_mutation(child1), flip_bit_mutation(child2)])

    population = new_population[:50]

best_knapsack = population[np.argmax([fitness(ind) for ind in population])]
print(f"Knapsack result: {fitness(best_knapsack)}")
print(f"Items selected: {best_knapsack}")
# Out:
# Knapsack result: 450
# Items selected: [1 0 1 1 1 0 0 1 0 0]

# %% [markdown]
# <h2> Task 11. Experiment with Genetic Algorithm (GA) Optimization Hyperparameters </h2>
# Identify key hyperparameters to experiment with, such as:
#
# *   Population Size: The number of individuals in the population
# *   Crossover type: Single point vs 2-point vs uniform
# *   Mutation Rate: The probability of mutating a chromosome.
# *   Selection Method: The method used for selecting parents from the populatio
# <p> 1.) Run the Genetic Algorithm with different combinations of population size, crossover type, mutation rate, and selection methods.
# For each combination, record metrics such as the best fitness value found and the number of generations required to converge to a solution.
# </p>
# <p> 2.) Report hyperparameters which will make GA never converge. Why?</p>

# %%
import numpy as np


def run_ga_experiment(population_size, crossover_type, mutation_rate, selection_method, problem='knapsack'):
    if problem == 'knapsack':
        population = [np.random.randint(0, 2, 10) for _ in range(population_size)]
        fitness_func = fitness
        mutation_func = lambda x: flip_bit_mutation(x, mutation_rate)
    else:
        population = [np.random.uniform(-5, 5, 12) for _ in range(population_size)]
        fitness_func = lambda x: -rastrigin_high_dimen(x)
        mutation_func = lambda x: gaussian_mutation(x, mutation_rate)

    crossover_funcs = {
        'single': single_point_crossover,
        'two_point': two_point_crossover,
        'uniform': uniform_crossover
    }
    crossover_func = crossover_funcs[crossover_type]

    best_fitness_history = []
    convergence_gen = None

    for generation in range(200):
        fitness_scores = [fitness_func(ind) for ind in population]
        current_best = max(fitness_scores)
        best_fitness_history.append(current_best)

        if generation > 10 and all(
                abs(best_fitness_history[i] - current_best) < 0.01 for i in range(generation - 10, generation)):
            if convergence_gen is None:
                convergence_gen = generation

        if selection_method == 'tournament':
            selected = tournament_selection(population, fitness_scores)
        else:
            selected = roulette_wheel_selection(population, fitness_scores)

        new_population = []
        for i in range(0, len(selected), 2):
            parent1, parent2 = selected[i], selected[i + 1] if i + 1 < len(selected) else selected[0]
            child1, child2 = crossover_func(parent1, parent2)
            new_population.extend([mutation_func(child1), mutation_func(child2)])

        population = new_population[:population_size]

    final_fitness = max([fitness_func(ind) for ind in population])
    return final_fitness, convergence_gen if convergence_gen else 200


experiments = [
    {'pop_size': 30, 'crossover': 'single', 'mut_rate': 0.1, 'selection': 'tournament'},
    {'pop_size': 100, 'crossover': 'uniform', 'mut_rate': 0.05, 'selection': 'roulette'},
    {'pop_size': 50, 'crossover': 'two_point', 'mut_rate': 0.2, 'selection': 'tournament'},
    {'pop_size': 20, 'crossover': 'single', 'mut_rate': 0.01, 'selection': 'roulette'},
    {'pop_size': 10, 'crossover': 'uniform', 'mut_rate': 0.5, 'selection': 'tournament'},
]

print("KNAPSACK EXPERIMENTS:")
print("PopSize | Crossover | MutRate | Selection  | BestFitness | Convergence")
print("-" * 70)

for exp in experiments:
    results = []
    for run in range(3):
        best_fit, conv_gen = run_ga_experiment(
            exp['pop_size'], exp['crossover'], exp['mut_rate'], exp['selection'], 'knapsack'
        )
        results.append((best_fit, conv_gen))

    avg_fitness = np.mean([r[0] for r in results])
    avg_convergence = np.mean([r[1] for r in results])

    print(
        f"{exp['pop_size']:6} | {exp['crossover']:9} | {exp['mut_rate']:7} | {exp['selection']:10} | {avg_fitness:11.1f} | {avg_convergence:10.1f}")

print("\nRASTRIGIN EXPERIMENTS:")
print("PopSize | Crossover | MutRate | Selection  | BestFitness | Convergence")
print("-" * 70)

for exp in experiments:
    results = []
    for run in range(3):
        best_fit, conv_gen = run_ga_experiment(
            exp['pop_size'], exp['crossover'], exp['mut_rate'], exp['selection'], 'rastrigin'
        )
        results.append((best_fit, conv_gen))

    avg_fitness = np.mean([r[0] for r in results])
    avg_convergence = np.mean([r[1] for r in results])

    print(
        f"{exp['pop_size']:6} | {exp['crossover']:9} | {exp['mut_rate']:7} | {exp['selection']:10} | {avg_fitness:11.1f} | {avg_convergence:10.1f}")

print("\nHYPERPARAMETERS THAT PREVENT CONVERGENCE:")
print("1. Mutation rate = 1.0 (100% mutation destroys good solutions)")
print("2. Population size = 1 (no diversity, no crossover possible)")
print("3. Mutation rate = 0.0 + identical initial population (no exploration)")
print("4. Very high mutation + very small population (random search)")
# Out:
# KNAPSACK EXPERIMENTS:
# PopSize | Crossover | MutRate | Selection  | BestFitness | Convergence
# ----------------------------------------------------------------------
#     30 | single    |     0.1 | tournament |       433.3 |       78.0
#    100 | uniform   |    0.05 | roulette   |       466.7 |       91.3
#     50 | two_point |     0.2 | tournament |       426.7 |      200.0
#     20 | single    |    0.01 | roulette   |       410.0 |       39.3
#     10 | uniform   |     0.5 | tournament |       256.7 |      200.0
#
# RASTRIGIN EXPERIMENTS:
# PopSize | Crossover | MutRate | Selection  | BestFitness | Convergence
# ----------------------------------------------------------------------
#     30 | single    |     0.1 | tournament |       -11.3 |      200.0
#    100 | uniform   |    0.05 | roulette   |       -10.5 |      200.0
#     50 | two_point |     0.2 | tournament |       -27.5 |      200.0
#     20 | single    |    0.01 | roulette   |       -40.6 |       80.0
#     10 | uniform   |     0.5 | tournament |       -79.9 |      200.0
#
# HYPERPARAMETERS THAT PREVENT CONVERGENCE:
# 1. Mutation rate = 1.0 (100% mutation destroys good solutions)
# 2. Population size = 1 (no diversity, no crossover possible)
# 3. Mutation rate = 0.0 + identical initial population (no exploration)
# 4. Very high mutation + very small population (random search)

# %% [markdown]
# <h2> Task 12. Use pyGAD library </h2>
# The pyGAD library is a powerful tool for implementing Genetic Algorithms in Python. Check their documentation: https://pygad.readthedocs.io/en/latest/
#
# 1.   pip install pygad
# 2.   Solve Knapsack problem defined above
# 3.   Solve rastrigin_high_dimen problem defined above
# 4.   Explore pyGAD hyperparameters

# %%
import pygad
import numpy as np

def knapsack_fitness_pygad(ga_instance, solution, solution_idx):
    items_list = list(knapsack_items.values())
    total_value = sum(solution[i] * items_list[i]['value'] for i in range(len(solution)))
    total_weight = sum(solution[i] * items_list[i]['weight'] for i in range(len(solution)))

    if total_weight > capacity:
        return 0
    return total_value

def rastrigin_fitness_pygad(ga_instance, solution, solution_idx):
    return -rastrigin_high_dimen(solution)

knapsack_ga = pygad.GA(
    num_generations=100,
    num_parents_mating=4,
    sol_per_pop=50,
    num_genes=10,
    fitness_func=knapsack_fitness_pygad,
    gene_type=int,
    gene_space=[0, 1]
)

knapsack_ga.run()
solution, fitness, _ = knapsack_ga.best_solution()
print(f"Knapsack Best Fitness: {fitness}")

rastrigin_ga = pygad.GA(
    num_generations=100,
    num_parents_mating=4,
    sol_per_pop=50,
    num_genes=12,
    fitness_func=rastrigin_fitness_pygad,
    gene_type=float,
    gene_space={'low': -5, 'high': 5}
)

rastrigin_ga.run()
solution, fitness, _ = rastrigin_ga.best_solution()
print(f"Rastrigin Best Fitness: {fitness} (Rastrigin value: {-fitness})")

print("\nHyperparameter exploration:")

for pop_size in [20, 50, 100]:
    ga = pygad.GA(
        num_generations=50,
        num_parents_mating=4,
        sol_per_pop=pop_size,
        num_genes=10,
        fitness_func=knapsack_fitness_pygad,
        gene_type=int,
        gene_space=[0, 1],
        suppress_warnings=True
    )
    ga.run()
    _, fitness, _ = ga.best_solution()
    print(f"Population {pop_size}: {fitness}")

for mut_rate in [10, 20, 30]:
    ga = pygad.GA(
        num_generations=50,
        num_parents_mating=4,
        sol_per_pop=50,
        num_genes=12,
        fitness_func=rastrigin_fitness_pygad,
        gene_type=float,
        gene_space={'low': -5, 'high': 5},
        mutation_percent_genes=mut_rate,
        suppress_warnings=True
    )
    ga.run()
    _, fitness, _ = ga.best_solution()
    print(f"Mutation {mut_rate}%: {fitness}")
# Out:
# Knapsack Best Fitness: 440
# Rastrigin Best Fitness: -4.1863093129174445 (Rastrigin value: 4.1863093129174445)
#
# Hyperparameter exploration:
# Population 20: 430
# Population 50: 450
# Population 100: 480
# Mutation 10%: -6.137486612998657
# Mutation 20%: -23.69189980271929
# Mutation 30%: -26.545459237941472

# %% [markdown]
# <h2> Task 13. The Needleman-Wunch Algorithm </h2>
# The goal of this task is to implement basic Needleman-Wunsch algorithm for sequence alignment and to experiment with various scoring parameters to understand their impact on alignment quality.
#
# 1.   Initialization: Create a scoring matrix initialized with zeros. The dimensions of the matrix should be based on the lengths of the two sequences being aligned.
# 2.   Scoring System: Define a scoring system that includes: Match Score: The score for matching characters, Mismatch Penalty: The penalty for aligning different characters, Gap Penalty: The penalty for introducing gaps in the alignment.
# 3.   Implement filling the Matrix: Fill in the scoring matrix according to the Needleman-Wunsch algorithm rules.
# 4.   Implement Traceback: After filling the matrix, perform a traceback to construct the aligned sequences.
# <p>
# Here are two sequences which you can use for example run:
# *   S1 = "ACTGACTGAACCCAA"
# *   S2 = "ACTGATCAA"
# </p>
# In order to check your implementation correctness use the following page: https://bioboot.github.io/bimm143_W20/class-material/nw/

# %%
import numpy as np

def fill_in_the_matrix(seq1, seq2, match_score=2, mismatch_penalty=-1, gap_penalty=-1):
    m, n = len(seq1), len(seq2)
    matrix = np.zeros((m + 1, n + 1))

    for i in range(1, m + 1):
        matrix[i][0] = i * gap_penalty
    for j in range(1, n + 1):
        matrix[0][j] = j * gap_penalty

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if seq1[i-1] == seq2[j-1]:
                diagonal = matrix[i-1][j-1] + match_score
            else:
                diagonal = matrix[i-1][j-1] + mismatch_penalty

            up = matrix[i-1][j] + gap_penalty
            left = matrix[i][j-1] + gap_penalty

            matrix[i][j] = max(diagonal, up, left)

    return matrix

def traceback(matrix, seq1, seq2, match_score=2, mismatch_penalty=-1, gap_penalty=-1):
    i, j = len(seq1), len(seq2)
    aligned_seq1, aligned_seq2 = "", ""

    while i > 0 or j > 0:
        if i > 0 and j > 0:
            if seq1[i-1] == seq2[j-1]:
                diagonal_score = matrix[i-1][j-1] + match_score
            else:
                diagonal_score = matrix[i-1][j-1] + mismatch_penalty

            if matrix[i][j] == diagonal_score:
                aligned_seq1 = seq1[i-1] + aligned_seq1
                aligned_seq2 = seq2[j-1] + aligned_seq2
                i -= 1
                j -= 1
            elif i > 0 and matrix[i][j] == matrix[i-1][j] + gap_penalty:
                aligned_seq1 = seq1[i-1] + aligned_seq1
                aligned_seq2 = "-" + aligned_seq2
                i -= 1
            else:
                aligned_seq1 = "-" + aligned_seq1
                aligned_seq2 = seq2[j-1] + aligned_seq2
                j -= 1
        elif i > 0:
            aligned_seq1 = seq1[i-1] + aligned_seq1
            aligned_seq2 = "-" + aligned_seq2
            i -= 1
        else:
            aligned_seq1 = "-" + aligned_seq1
            aligned_seq2 = seq2[j-1] + aligned_seq2
            j -= 1

    return aligned_seq1, aligned_seq2

S1 = "ACTGACTGAACCCAA"
S2 = "ACTGATCAA"

matrix = fill_in_the_matrix(S1, S2)
aligned_s1, aligned_s2 = traceback(matrix, S1, S2)

print(f"Aligned S1: {aligned_s1}")
print(f"Aligned S2: {aligned_s2}")
print(f"Score: {matrix[-1][-1]}")
# Out:
# Aligned S1: ACTGACTGAACCCAA
# Aligned S2: ACTGA-T-----CAA
# Score: 12.0

# %% [markdown]
# <h2> Task 14. Time complexity of The Needleman-Wunch Algorithm </h2>
#
#
# 1.   What is the time complexity of The Needleman-Wunch Algorith? Both filling in and traceback
# 2.   Why?
# 3.   When we say time complexity, we mean O() annotation. This means worst possible case. Using the implementation from Task 12. demonstrate the worst time complexity or worst possible case.

# %% [markdown]
# Your answer here....

# %%
def measure_nw_complexity(seq_len1, seq_len2):
    seq1 = ''.join(np.random.choice(['A', 'T', 'G', 'C'], seq_len1))
    seq2 = ''.join(np.random.choice(['A', 'T', 'G', 'C'], seq_len2))

    start_time = time.time()
    matrix = fill_in_the_matrix(seq1, seq2)
    traceback(matrix, seq1, seq2)
    return time.time() - start_time

print("seq_len1 | seq_len2 | total_time (s) | time_per_cell (s) | m×n")
print("-" * 65)

test_cases = [(50, 50), (100, 100), (150, 150), (200, 200), (300, 300), (400, 400)]
times, m_n_values, times_per_cell = [], [], []

for seq_len1, seq_len2 in test_cases:
    total_time = measure_nw_complexity(seq_len1, seq_len2)
    mn_product = seq_len1 * seq_len2
    time_per_cell = total_time / mn_product

    print(f"{seq_len1:8} | {seq_len2:8} | {total_time:12.4f} | {time_per_cell:13.8f} | {mn_product}")

    times.append(total_time)
    m_n_values.append(mn_product)
    times_per_cell.append(time_per_cell)

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(m_n_values, times, 'o-')
plt.xlabel('m × n')
plt.ylabel('Total Time (s)')
plt.title('Total Time vs m×n')

plt.subplot(1, 3, 2)
plt.plot([tc[0] for tc in test_cases], times, 'o-', color='green')
plt.xlabel('Sequence Length')
plt.ylabel('Total Time (s)')
plt.title('Time vs Sequence Length')

plt.subplot(1, 3, 3)
plt.plot(m_n_values, times_per_cell, 'o-', color='red')
plt.xlabel('m × n')
plt.ylabel('Time per Cell (s)')
plt.title('Time per Cell Calculation')

plt.tight_layout()
plt.show()

print("\nTime Complexity Analysis:")
print("1. Fill Matrix: O(m×n) - must compute every cell in (m+1)×(n+1) matrix")
print("2. Traceback: O(m+n) - maximum path length from bottom-right to top-left")
print("3. Overall: O(m×n) - filling matrix dominates the total complexity")
print("\nWorst case: Any two sequences of length m and n require full m×n computation")

seq1_worst = 'A' * 200
seq2_worst = 'T' * 200
start_time = time.time()
matrix_worst = fill_in_the_matrix(seq1_worst, seq2_worst)
worst_time = time.time() - start_time
print(f"Worst case demonstration (200×200 different sequences): {worst_time:.4f}s")
# Out:
# seq_len1 | seq_len2 | total_time (s) | time_per_cell (s) | m×n
# -----------------------------------------------------------------
#       50 |       50 |       0.0018 |    0.00000074 | 2500
#      100 |      100 |       0.0076 |    0.00000076 | 10000
#      150 |      150 |       0.0154 |    0.00000069 | 22500
#      200 |      200 |       0.0258 |    0.00000065 | 40000
#      300 |      300 |       0.0586 |    0.00000065 | 90000
#      400 |      400 |       0.1053 |    0.00000066 | 160000
# Time Complexity Analysis:
# 1. Fill Matrix: O(m×n) - must compute every cell in (m+1)×(n+1) matrix
# 2. Traceback: O(m+n) - maximum path length from bottom-right to top-left
# 3. Overall: O(m×n) - filling matrix dominates the total complexity
#
# Worst case: Any two sequences of length m and n require full m×n computation
# Worst case demonstration (200×200 different sequences): 0.0259s

# %% [markdown]
# <h2> Task 15. Implement basic Gradient Descent </h2>
# The goal of this task is to implement the Basic Gradient Descent algorithm to optimize a given objective function.
#
#
#
# 1.   Select an Objective Function, I would recommend quadratic because this is often used in examples. f(x)=ax^2 + bx + c. Feel free to try complex ones used in tasks above
#
# 2.   Define a function to compute the gradient of the objective function. We will assume we do not know how to compute the gradient, therefore we have to estimate it. Implement numerical gradient estimation
# 3.   Update Rule: Implement the update rule for the gradient descent based on learning rate

# %%
def quadratic_objective_function(x):
    return (x - 3) ** 2 + 1

def numerical_gradient(f, x, h=1e-5):
    return (f(x + h) - f(x - h)) / (2 * h)

def gradient_descent(starting_point, learning_rate, num_iterations):
    x = starting_point
    x_history = []
    f_history = []

    for _ in range(num_iterations):
        x_history.append(x)
        f_history.append(quadratic_objective_function(x))

        grad = numerical_gradient(quadratic_objective_function, x)
        x = x - learning_rate * grad

    return x, f_history, x_history

final_x, f_hist, x_hist = gradient_descent(5, 0.1, 20)
print(f"Final x: {final_x:.6f}")
print(f"Final f(x): {quadratic_objective_function(final_x):.6f}")
# Out:
# Final x: 3.023058
# Final f(x): 1.000532

# %% [markdown]
# <h2> Task 16. Experiment basic Gradient Descent </h2>
# To compare the effect of varying the step size h used in the numerical gradient estimation and the learning rate in the Gradient Descent algorithm, we will set up an experiment using both the exact gradient of a quadratic function and the numerically estimated gradient. We will analyze how changes in ℎ and the learning rate (lr) affect convergence.
#
#
#
# 1.   Experiment with lr,h and exact derivative vs numerical estimate
# 2.   Record and visualize results
# 3.   Use f_history and x_history to visualize path during the optimization
# 4.   Draw conclusions and support them with figures from (3.). How is h and lr affecting convergance? Exact derivative vs numerical estimate?

# %%
def the_exact_derivative(x):
    return 2 * (x - 3)

def gradient_descent_exact(starting_point, learning_rate, num_iterations):
    x = starting_point
    x_history = []
    f_history = []

    for _ in range(num_iterations):
        x_history.append(x)
        f_history.append(quadratic_objective_function(x))

        grad = the_exact_derivative(x)
        x = x - learning_rate * grad

    return x, f_history, x_history

starting_point = 5
h_values = [0.1, 1e-3, 1e-5, 1e-8, 1e-10]
learning_rates = [0.01, 0.1, 0.3, 0.5, 0.8]
num_iterations = 20

results = {}

for h in h_values:
    for lr in learning_rates:
        final_x_exact, f_hist_exact, x_hist_exact = gradient_descent_exact(starting_point, lr, num_iterations)

        final_x_numerical, f_hist_numerical, x_hist_numerical = gradient_descent(starting_point, lr, num_iterations)

        results[(h, lr)] = {
            'exact': {
                'final_x': final_x_exact,
                'final_f': quadratic_objective_function(final_x_exact),
                'converged': abs(final_x_exact - 3) < 0.01,
                'f_history': f_hist_exact,
                'x_history': x_hist_exact
            },
            'numerical': {
                'final_x': final_x_numerical,
                'final_f': quadratic_objective_function(final_x_numerical),
                'converged': abs(final_x_numerical - 3) < 0.01,
                'f_history': f_hist_numerical,
                'x_history': x_hist_numerical
            }
        }

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

h_test = 1e-5
lr_test = 0.1
test_result = results[(h_test, lr_test)]

axes[0,0].plot(test_result['exact']['f_history'], label='Exact', marker='o')
axes[0,0].plot(test_result['numerical']['f_history'], label='Numerical', marker='s')
axes[0,0].set_title(f'Function Value (h={h_test}, lr={lr_test})')
axes[0,0].legend()

axes[0,1].plot(test_result['exact']['x_history'], label='Exact', marker='o')
axes[0,1].plot(test_result['numerical']['x_history'], label='Numerical', marker='s')
axes[0,1].axhline(y=3, color='red', linestyle='--', label='Target')
axes[0,1].set_title(f'Position Path (h={h_test}, lr={lr_test})')
axes[0,1].legend()

convergence_exact = [results[(h, 0.1)]['exact']['converged'] for h in h_values]
convergence_numerical = [results[(h, 0.1)]['numerical']['converged'] for h in h_values]
axes[1,0].bar([str(h) for h in h_values], convergence_exact, alpha=0.7, label='Exact')
axes[1,0].bar([str(h) for h in h_values], convergence_numerical, alpha=0.7, label='Numerical')
axes[1,0].set_title('Convergence vs h (lr=0.1)')
axes[1,0].legend()

convergence_lr_exact = [results[(1e-5, lr)]['exact']['converged'] for lr in learning_rates]
convergence_lr_numerical = [results[(1e-5, lr)]['numerical']['converged'] for lr in learning_rates]
axes[1,1].bar([str(lr) for lr in learning_rates], convergence_lr_exact, alpha=0.7, label='Exact')
axes[1,1].bar([str(lr) for lr in learning_rates], convergence_lr_numerical, alpha=0.7, label='Numerical')
axes[1,1].set_title('Convergence vs lr (h=1e-5)')
axes[1,1].legend()

plt.tight_layout()
plt.show()

print("Summary Results:")
print("=" * 50)
for lr in [0.1, 0.5]:
    for h in [1e-5, 1e-10]:
        exact_final = results[(h, lr)]['exact']['final_x']
        numerical_final = results[(h, lr)]['numerical']['final_x']
        print(f"h={h}, lr={lr}: Exact={exact_final:.6f}, Numerical={numerical_final:.6f}")
# Out:
# Summary Results:
# ==================================================
# h=1e-05, lr=0.1: Exact=3.023058, Numerical=3.023058
# h=1e-10, lr=0.1: Exact=3.023058, Numerical=3.023058
# h=1e-05, lr=0.5: Exact=3.000000, Numerical=3.000000
# h=1e-10, lr=0.5: Exact=3.000000, Numerical=3.000000

# %% [markdown]
# The larger h is, the less precise it becomes because the derivative approximation becomes worse. However, if we put smaller h then the approximation becomes better and more accurate. From our results we see that h doesn't have much effect on convergence as long as it's in the optimal range like 1e-5 to 1e-8. While lr is much more important - when we put larger lr then we take bigger steps and can reach the minimum faster, however if it's too large we can skip our minimum. When lr is smaller like 0.1 then it's too slow and doesn't manage to converge in 20 iterations, unlike when we put lr=0.5 then it converges excellently. From the graphs we see that exact and numerical give identical results when h is optimal, which means that numerical approximation works just as well as exact derivative.

# %% [markdown]
# <h2> Task 17. The end game - part 1</h2>
# The goal of this task is to tackle a challenging optimization problem using different optimization algorithms. The problem is defined bellow, select appropriate algorithms, compare their performances, and utilize a simpler algorithm (Hill Climber) to fine-tune hyperparameters for more complex algorithms.
#
#
# 1.   Understand the Problem: Clearly define the optimization problem, including the objective function, constraints, and any relevant parameters.
#
# 2.   Select Algorithms: Choose at least two algorithms for the problem optimization. Justify the choice of algorithms based on their suitability for the selected problem.
# 3. Implement the Algorithms
# 4. Hyperparameter Optimization with a Simple Algorithm (Hill Climber)
# 5. Experimentation and Comparison: Run experiments using the implemented algorithms with the chosen hyperparameters.
# Record metrics such as: Best solution found, Execution time, Number of iterations/generations. Analyze and compare the performance of the algorithms based on these metrics.
# 6. Analyze Results: Create plots to visualize the performance of the algorithms
#
# Problem Definition
# In the Vehicle Routing Problem VRP, the goal is to determine the optimal routes for a fleet of vehicles to service a set of customers while minimizing the total distance traveled, respecting vehicle capacities and customer demands.
#
# *  Multiple Vehicles with Different Capacities: Instead of having vehicles with the same capacity, introduce vehicles that have different maximum capacities.
#
# *  Time Windows: Each customer can have specific time windows during which they must be serviced. If a vehicle arrives outside of this window, it may incur a penalty or be unable to service that customer.
#
# *  Service Times: Include service times at each customer location. This means that the total route time will be affected not only by travel distance but also by the time spent servicing each customer.
#
# *  Limited Number of Routes: Set a limit on the number of routes that can be used, forcing optimization under tighter constraints.
#
# *  Penalty for Late Deliveries: Introduce a penalty for delivering goods late, based on how late the vehicle arrives at a customer.
#
# <h3>Params in the data </h3>
#
# <p> demand:This represents the quantity of goods or services that the customer
# requires. It is important for the vehicle routing problem as it dictates how much of the vehicle's capacity is used when serving that customer. For example, if a customer has a demand of 10, the vehicle must have at least that much capacity to service this customer. </p>
# <p> (x, y): This tuple represents the coordinates of the customer's location on a two-dimensional plane. The coordinates are used to calculate the distance between customers and the depot. For example, (3, 5) means the customer is located at 3 units on the x-axis and 5 units on the y-axis. </p>
# <p> service_time: This indicates the amount of time required to service the customer once the vehicle arrives at their location. Service time affects the overall route time, as it adds to the total time spent at each customer before moving on to the next one. </p>
# <p>  (earliest_time, latest_time): This tuple defines the time window during which the customer must be serviced.
# earliest_time: The earliest moment the vehicle can arrive at the customer's location. </p>
# <p>  latest_time: The latest moment the vehicle can arrive without incurring a penalty or missing the service. This aspect is crucial for routing decisions, as it adds constraints to the schedule that must be respected. </p>

# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt

customers = [
    ('Customer1', 5, (1, 2), 2, (0, 10)),
    ('Customer2', 10, (2, 3), 3, (2, 12)),
    ('Customer3', 8, (3, 1), 1, (1, 8)),
    ('Customer4', 6, (4, 4), 2, (3, 15)),
    ('Customer5', 12, (5, 5), 4, (5, 15)),
    ('Customer6', 7, (6, 2), 1, (0, 5)),
    ('Customer7', 15, (7, 8), 3, (5, 20)),
    ('Customer8', 4, (8, 3), 2, (3, 9)),
    ('Customer9', 9, (1, 7), 1, (2, 10)),
    ('Customer10', 11, (4, 6), 2, (4, 14)),
    ('Customer11', 14, (2, 5), 3, (1, 9)),
    ('Customer12', 6, (5, 7), 2, (3, 12)),
    ('Customer13', 10, (3, 3), 4, (2, 10)),
    ('Customer14', 8, (6, 5), 1, (0, 4)),
    ('Customer15', 12, (1, 4), 2, (1, 7)),
    ('Customer16', 5, (4, 2), 3, (3, 8)),
    ('Customer17', 7, (8, 6), 1, (4, 10)),
    ('Customer18', 9, (5, 3), 2, (2, 9)),
    ('Customer19', 11, (3, 6), 2, (4, 11)),
    ('Customer20', 13, (2, 8), 4, (3, 15)),
]
depot = (0, 0)
vehicles = [
    {'vehicle_id': 'Vehicle1', 'capacity': 70},
    {'vehicle_id': 'Vehicle2', 'capacity': 65},
    {'vehicle_id': 'Vehicle3', 'capacity': 80},
]
routing_rules = {
    'max_distance_per_route': 30,
    'max_customers_per_route': 5,
}

def distance(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def calculate_route_time_and_penalties(route):
    if not route:
        return 0, 0

    current_time = 0
    total_distance = 0
    time_penalty = 0

    first_customer = customers[route[0]]
    current_time += distance(depot, first_customer[2])
    total_distance += distance(depot, first_customer[2])

    earliest, latest = first_customer[4]
    if current_time < earliest:
        current_time = earliest
    elif current_time > latest:
        time_penalty += (current_time - latest) * 50

    current_time += first_customer[3]

    for i in range(1, len(route)):
        prev_customer = customers[route[i-1]]
        curr_customer = customers[route[i]]

        travel_time = distance(prev_customer[2], curr_customer[2])
        current_time += travel_time
        total_distance += travel_time

        earliest, latest = curr_customer[4]
        if current_time < earliest:
            current_time = earliest
        elif current_time > latest:
            time_penalty += (current_time - latest) * 50

        current_time += curr_customer[3]

    last_customer = customers[route[-1]]
    total_distance += distance(last_customer[2], depot)

    return total_distance, time_penalty

def evaluate(solution):
    total_distance = 0
    penalty = 0
    assigned = set()

    for v_idx, route in enumerate(solution):
        if not route:
            continue

        dist, time_penalty = calculate_route_time_and_penalties(route)
        total_distance += dist
        penalty += time_penalty

        demand = sum(customers[i][1] for i in route)
        if demand > vehicles[v_idx]['capacity']:
            penalty += (demand - vehicles[v_idx]['capacity']) * 100
        if dist > routing_rules['max_distance_per_route']:
            penalty += (dist - routing_rules['max_distance_per_route']) * 50
        if len(route) > routing_rules['max_customers_per_route']:
            penalty += (len(route) - routing_rules['max_customers_per_route']) * 100

        assigned.update(route)

    penalty += (len(customers) - len(assigned)) * 200
    return total_distance + penalty

def initial_solution():
    indices = list(range(len(customers)))
    random.shuffle(indices)
    solution = [[] for _ in vehicles]

    for idx in indices:
        best_vehicle = min(range(len(vehicles)), key=lambda v: len(solution[v]))
        solution[best_vehicle].append(idx)

    return solution

def neighbor(solution):
    new_sol = [route[:] for route in solution]
    if random.random() < 0.5:
        routes = [i for i, r in enumerate(new_sol) if len(r) > 1]
        if routes:
            r_idx = random.choice(routes)
            i, j = random.sample(range(len(new_sol[r_idx])), 2)
            new_sol[r_idx][i], new_sol[r_idx][j] = new_sol[r_idx][j], new_sol[r_idx][i]
    else:
        from_routes = [i for i, r in enumerate(new_sol) if r]
        if len(from_routes) >= 2:
            from_idx = random.choice(from_routes)
            to_idx = random.choice([i for i in range(len(new_sol)) if i != from_idx])
            if new_sol[from_idx]:
                customer = new_sol[from_idx].pop(random.randrange(len(new_sol[from_idx])))
                new_sol[to_idx].append(customer)
    return new_sol

def simulated_annealing(temp, cooling, iterations):
    solution = initial_solution()
    best_solution = solution
    best_cost = evaluate(solution)
    costs = []

    for _ in range(iterations):
        new_solution = neighbor(solution)
        new_cost = evaluate(new_solution)
        delta = new_cost - best_cost

        if delta < 0 or random.random() < np.exp(-delta / temp):
            solution = new_solution
            if new_cost < best_cost:
                best_solution = new_solution
                best_cost = new_cost

        temp *= cooling
        costs.append(best_cost)

    return best_solution, best_cost, costs

def crossover(p1, p2):
    child = [[] for _ in vehicles]
    assigned = set()

    for i in range(len(vehicles)):
        if p1[i] and random.random() < 0.5:
            for c in p1[i][:2]:
                if c not in assigned:
                    child[i].append(c)
                    assigned.add(c)

    for c in range(len(customers)):
        if c not in assigned:
            min_route = min(range(len(vehicles)), key=lambda i: len(child[i]))
            child[min_route].append(c)

    return child

def genetic_algorithm(pop_size, mutation_rate, generations):
    population = [initial_solution() for _ in range(pop_size)]
    best_cost = float('inf')
    costs = []

    for _ in range(generations):
        scored = [(sol, evaluate(sol)) for sol in population]
        scored.sort(key=lambda x: x[1])

        if scored[0][1] < best_cost:
            best_solution = scored[0][0]
            best_cost = scored[0][1]
        costs.append(best_cost)

        new_pop = [scored[0][0]]
        while len(new_pop) < pop_size:
            p1 = random.choice(scored[:pop_size//2])[0]
            p2 = random.choice(scored[:pop_size//2])[0]
            child = crossover(p1, p2)
            if random.random() < mutation_rate:
                child = neighbor(child)
            new_pop.append(child)

        population = new_pop

    return best_solution, best_cost, costs

def hill_climber_optimize(algo_type):
    if algo_type == 'SA':
        best_params = {'temp': 100, 'cooling': 0.95, 'iter': 1000}
        for _ in range(10):
            params = best_params.copy()
            param = random.choice(['temp', 'cooling', 'iter'])
            if param == 'temp':
                params['temp'] += random.choice([-20, 20])
            elif param == 'cooling':
                params['cooling'] += random.choice([-0.02, 0.02])
            else:
                params['iter'] += random.choice([-200, 200])

            _, cost, _ = simulated_annealing(params['temp'], params['cooling'], params['iter'])
            _, best_cost, _ = simulated_annealing(best_params['temp'], best_params['cooling'], best_params['iter'])

            if cost < best_cost:
                best_params = params
        return best_params
    else:
        best_params = {'pop': 50, 'mut': 0.1, 'gen': 100}
        for _ in range(10):
            params = best_params.copy()
            param = random.choice(['pop', 'mut', 'gen'])
            if param == 'pop':
                params['pop'] += random.choice([-10, 10])
            elif param == 'mut':
                params['mut'] += random.choice([-0.05, 0.05])
            else:
                params['gen'] += random.choice([-20, 20])

            _, cost, _ = genetic_algorithm(params['pop'], params['mut'], params['gen'])
            _, best_cost, _ = genetic_algorithm(best_params['pop'], best_params['mut'], best_params['gen'])

            if cost < best_cost:
                best_params = params
        return best_params

sa_params = hill_climber_optimize('SA')
ga_params = hill_climber_optimize('GA')
print(f"New SA parameters after hill climber: {sa_params}")
print(f"New GA parameters after hill climber: {ga_params}")
sa_times, ga_times = [], []
sa_costs, ga_costs = [], []

for _ in range(3):
    start = time.time()
    _, cost, history = simulated_annealing(sa_params['temp'], sa_params['cooling'], sa_params['iter'])
    sa_times.append(time.time() - start)
    sa_costs.append(cost)

    start = time.time()
    _, cost, history = genetic_algorithm(ga_params['pop'], ga_params['mut'], ga_params['gen'])
    ga_times.append(time.time() - start)
    ga_costs.append(cost)

print(f"\nSA: avg cost {np.mean(sa_costs):.1f}, avg time {np.mean(sa_times):.3f}s")
print(f"GA: avg cost {np.mean(ga_costs):.1f}, avg time {np.mean(ga_times):.3f}s")

_, _, sa_conv = simulated_annealing(sa_params['temp'], sa_params['cooling'], sa_params['iter'])
_, _, ga_conv = genetic_algorithm(ga_params['pop'], ga_params['mut'], ga_params['gen'])

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(sa_conv[:200], label='SA')
plt.plot(ga_conv, label='GA')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

plt.subplot(1, 2, 2)
x = [0, 1]
plt.bar(x, [np.mean(sa_costs), np.mean(ga_costs)], width=0.4)
plt.xticks(x, ['SA', 'GA'])
plt.ylabel('Average Cost')
plt.tight_layout()
plt.show()
# Out:
# New SA parameters after hill climber: {'temp': 80, 'cooling': 0.99, 'iter': 1000}
# New GA parameters after hill climber: {'pop': 40, 'mut': 0.1, 'gen': 100}
#
# SA: avg cost 7518.9, avg time 0.036s
# GA: avg cost 10602.1, avg time 0.172s

# %% [markdown]
# <h2> Task 18. The end game - part 2 </h2>
# The goal of this task is for you to research, implement, and analyze a <b> at least two </b> metaheuristic optimization algorithm that was not covered in class. You will apply the algorithm to a chosen optimization problem, demonstrating its effectiveness and comparing it to other methods.
# <p> Some ideas: </p>
# Gravitational Search Algorithm, Bat Algorithm, Differential Evolution (DE), Cuckoo Search (CS), Firefly Algorithm, Harmony Search (HS), Tabu Search, Affine GAP Cost Needleman-Wunch etc....
# <h3> There are many algorithms to consider...</h3>
# You have to:
#
#
# *   Implement the algorithm
# *   What is the time complexity?
# *   Analyze hyperparams
# *   Visualize the performance
# *   Pick objective function of your choice

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

def rastrigin(x):
    A = 10
    n = len(x)
    return A * n + sum(x_i**2 - A * np.cos(2 * np.pi * x_i) for x_i in x)

# Differential Evolution
def differential_evolution(pop_size, F, CR, max_iter, dim, bounds):
    population = np.random.uniform(bounds[0], bounds[1], (pop_size, dim))
    fitness = np.array([rastrigin(ind) for ind in population])
    best_idx = np.argmin(fitness)
    best_fitness = fitness[best_idx]
    history = []

    for _ in range(max_iter):
        for i in range(pop_size):
            a, b, c = np.random.choice(pop_size, 3, replace=False)
            mutant = population[a] + F * (population[b] - population[c])
            mutant = np.clip(mutant, bounds[0], bounds[1])

            trial = population[i].copy()
            for j in range(dim):
                if np.random.rand() < CR:
                    trial[j] = mutant[j]

            trial_fitness = rastrigin(trial)
            if trial_fitness < fitness[i]:
                population[i] = trial
                fitness[i] = trial_fitness
                if trial_fitness < best_fitness:
                    best_idx = i
                    best_fitness = trial_fitness

        history.append(best_fitness)

    return population[best_idx], best_fitness, history

# Firefly Algorithm
def firefly_algorithm(n_fireflies, alpha, beta0, gamma, max_iter, dim, bounds):
    fireflies = np.random.uniform(bounds[0], bounds[1], (n_fireflies, dim))
    brightness = np.array([rastrigin(f) for f in fireflies])
    best_idx = np.argmin(brightness)
    best_fitness = brightness[best_idx]
    history = []

    for _ in range(max_iter):
        for i in range(n_fireflies):
            for j in range(n_fireflies):
                if brightness[j] < brightness[i]:
                    r = np.linalg.norm(fireflies[i] - fireflies[j])
                    beta = beta0 * np.exp(-gamma * r**2)
                    fireflies[i] += beta * (fireflies[j] - fireflies[i]) + alpha * np.random.randn(dim)
                    fireflies[i] = np.clip(fireflies[i], bounds[0], bounds[1])
                    brightness[i] = rastrigin(fireflies[i])

                    if brightness[i] < best_fitness:
                        best_idx = i
                        best_fitness = brightness[i]

        alpha *= 0.95
        history.append(best_fitness)

    return fireflies[best_idx], best_fitness, history

print("Time Complexity Analysis:")
print("=" * 60)

dimensions = [2, 5, 10, 15, 20]
de_times = []
ff_times = []

for dim in dimensions:
    start = time.time()
    differential_evolution(30, 0.8, 0.9, 100, dim, (-5.12, 5.12))
    de_times.append(time.time() - start)

    start = time.time()
    firefly_algorithm(30, 0.5, 1.0, 0.01, 100, dim, (-5.12, 5.12))
    ff_times.append(time.time() - start)

print(f"DE: O(pop_size × max_iter × dim)")
print(f"Firefly: O(n_fireflies² × max_iter × dim)")

print("\nGrowth Rate Analysis:")
for i in range(1, len(dimensions)):
    de_growth = (de_times[i] - de_times[i-1]) / (dimensions[i] - dimensions[i-1])
    ff_growth = (ff_times[i] - ff_times[i-1]) / (dimensions[i] - dimensions[i-1])
    print(f"Dim {dimensions[i-1]}→{dimensions[i]}: DE={de_growth:.4f}s/dim, FF={ff_growth:.4f}s/dim")

print("\nHyperparameter Optimization:")
print("=" * 60)

dim = 10
bounds = (-5.12, 5.12)

F_values = [0.3, 0.5, 0.8, 1.0]
CR_values = [0.1, 0.5, 0.7, 0.9]
de_results = {}

for F in F_values:
    for CR in CR_values:
        costs = []
        for _ in range(5):
            _, cost, _ = differential_evolution(30, F, CR, 200, dim, bounds)
            costs.append(cost)
        de_results[(F, CR)] = np.mean(costs)

alpha_values = [0.1, 0.5, 1.0]
gamma_values = [0.001, 0.01, 0.1]
ff_results = {}

for alpha in alpha_values:
    for gamma in gamma_values:
        costs = []
        for _ in range(5):
            _, cost, _ = firefly_algorithm(30, alpha, 1.0, gamma, 200, dim, bounds)
            costs.append(cost)
        ff_results[(alpha, gamma)] = np.mean(costs)

best_de = min(de_results, key=de_results.get)
best_ff = min(ff_results, key=ff_results.get)
print(f"Best DE params: F={best_de[0]}, CR={best_de[1]}, cost={de_results[best_de]:.2f}")
print(f"Best Firefly params: alpha={best_ff[0]}, gamma={best_ff[1]}, cost={ff_results[best_ff]:.2f}")

_, _, de_hist = differential_evolution(50, best_de[0], best_de[1], 500, 10, bounds)
_, _, ff_hist = firefly_algorithm(50, best_ff[0], 1.0, best_ff[1], 500, 10, bounds)

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(dimensions, de_times, 'o-', label='DE')
plt.plot(dimensions, ff_times, 's-', label='Firefly')
plt.xlabel('Dimensions')
plt.ylabel('Time (s)')
plt.title('Time Complexity')
plt.legend()

plt.subplot(1, 3, 2)
de_matrix = np.zeros((4, 4))
for i, F in enumerate([0.3, 0.5, 0.8, 1.0]):
    for j, CR in enumerate([0.1, 0.5, 0.7, 0.9]):
        de_matrix[i, j] = de_results[(F, CR)]
plt.imshow(de_matrix, cmap='viridis', aspect='auto')
plt.colorbar(label='Cost')
plt.xlabel('CR')
plt.ylabel('F')
plt.title('DE Hyperparameters')
plt.xticks([0,1,2,3], ['0.1','0.5','0.7','0.9'])
plt.yticks([0,1,2,3], ['0.3','0.5','0.8','1.0'])

plt.subplot(1, 3, 3)
plt.plot(de_hist[:200], label='DE')
plt.plot(ff_hist[:200], label='Firefly')
plt.xlabel('Iteration')
plt.ylabel('Best Cost')
plt.title('Convergence')
plt.legend()

plt.tight_layout()
plt.show()

print("\nNon-convergence Analysis:")
print("=" * 60)

_, cost_f0, hist_f0 = differential_evolution(30, 0.0, 0.9, 100, 10, bounds)
_, cost_cr0, hist_cr0 = differential_evolution(30, 0.8, 0.0, 100, 10, bounds)
_, cost_gamma_large, hist_gamma_large = firefly_algorithm(30, 0.5, 1.0, 10.0, 100, 10, bounds)

plt.figure(figsize=(8, 4))
plt.plot(hist_f0, label='DE (F=0)')
plt.plot(hist_cr0, label='DE (CR=0)')
plt.plot(hist_gamma_large, label='Firefly (γ=10)')
plt.xlabel('Iteration')
plt.ylabel('Best Cost')
plt.title('Non-convergence Examples')
plt.legend()
plt.show()

print("DE with F=0: No mutation → no exploration → stuck at initial random solution")
print("DE with CR=0: No crossover → no information exchange → poor convergence")
print("Firefly with large γ: Attraction decays too fast → fireflies don't move → no optimization")
# Out:
# Time Complexity Analysis:
# ============================================================
# DE: O(pop_size × max_iter × dim)
# Firefly: O(n_fireflies² × max_iter × dim)
#
# Growth Rate Analysis:
# Dim 2→5: DE=-0.0006s/dim, FF=0.0133s/dim
# Dim 5→10: DE=0.0022s/dim, FF=0.0232s/dim
# Dim 10→15: DE=0.0023s/dim, FF=0.0237s/dim
# Dim 15→20: DE=0.0029s/dim, FF=0.0174s/dim
#
# Hyperparameter Optimization:
# ============================================================
# Best DE params: F=1.0, CR=0.1, cost=4.27
# Best Firefly params: alpha=1.0, gamma=0.01, cost=9.75
# Non-convergence Analysis:
# ============================================================
# DE with F=0: No mutation → no exploration → stuck at initial random solution
# DE with CR=0: No crossover → no information exchange → poor convergence
# Firefly with large γ: Attraction decays too fast → fireflies don't move → no optimization
